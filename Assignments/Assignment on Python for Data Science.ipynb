# %% [markdown]
# # Assignment on Python for Data Science

# %% [markdown]
# #### 1. Read the dataset to python environment.
# #### 2. Display the columns in the dataset.

# %%
import pandas as pd


df = pd.read_excel('iris.xls')
print(df.head())
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# #### 3. Calculate the mean of each column of the dataset.

# %%
df.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# #### 4. Check for the null values present in the dataset.

# %%
df.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
df.isnull().any()
# Out:
# SL                False
# SW                False
# PL                False
# PW                False
# Classification    False
# dtype: bool

# %% [markdown]
# #### 5. Perform meaningful visualizations using the dataset.

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['SL'].plot()
# Out:
# <AxesSubplot:>

# %%
df['SW'].plot()
# Out:
# <AxesSubplot:>

# %%
df['PL'].plot()
# Out:
# <AxesSubplot:>

# %%
df['PW'].plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="scatter", x="SL", y="SW")
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
import seaborn as sns
sns.jointplot(x="SL", y="SW", data=df, size=5)
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>
